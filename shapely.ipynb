# %%
import sys
sys.path.insert(0, './src/')
from tube import Cross
from matplotlib import pyplot as plt
from shapely.geometry import LineString
import numpy as np

# %%
C = Cross(5,1)
C.build_geometry(n_jobs=10)

# %%
plt.figure(figsize=(10,10))
polygon_pts = C.boundary
polygon_pts = np.concatenate([polygon_pts, polygon_pts[0:1]])
plt.plot(polygon_pts[:,0], polygon_pts[:,1])
plt.plot(x,y)

# %%
line = LineString(polygon_pts)
dilated = line.buffer(0.1)
eroded = dilated.buffer(-0.04)

# %%
x,y = eroded.interiors[0].xy
