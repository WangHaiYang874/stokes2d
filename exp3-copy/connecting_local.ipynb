# %% [markdown]
# With no extra term at all

# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle

import sys
sys.path.insert(0,'../src/')
from utils import *

# %%
with open('v0.pickle','rb') as f:
    pipes = pickle.load(f)
pipes = [p for p,_ in pipes]

# %%
fig, axes = plt.subplots(8,1,figsize=(10,30))

for p,a in zip(pipes, axes):
    for c in p.callbacks:
        a.semilogy(c.residuals)

# %%
for p in pipes:
    for o in p.omegas:
        print(np.abs(np.real(np.sum(o*np.conjugate(p.dt)))), end ='\t')
    print()
# Out:
# 4.945377440890297e-12	4.035882739117369e-12
# 5.684341886080802e-14
# 5.684341886080802e-14
# 8.185452315956354e-12	2.0179413695586845e-11
# 4.945377440890297e-12	4.035882739117369e-12
# 5.684341886080802e-14
# 5.684341886080802e-14
# 8.185452315956354e-12	2.0179413695586845e-11
# 3.637978807091713e-12	5.229594535194337e-12
# 7.275957614183426e-12	7.275957614183426e-12
# 4.945377440890297e-12	4.035882739117369e-12
# 5.684341886080802e-14
# 5.684341886080802e-14
# 8.185452315956354e-12	2.0179413695586845e-11
# 4.945377440890297e-12	4.035882739117369e-12
# 5.684341886080802e-14
# 5.684341886080802e-14
# 8.185452315956354e-12	2.0179413695586845e-11
# 3.637978807091713e-12	5.229594535194337e-12
# 7.275957614183426e-12	7.275957614183426e-12
# 9.094947017729282e-13	3.637978807091713e-12
# 1.5916157281026244e-12	3.637978807091713e-12
