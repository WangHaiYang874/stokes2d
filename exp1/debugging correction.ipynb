# %%
import sys
sys.path.insert(0,'../src/')

from utils import *
from multiply_connected_pipe import *

from matplotlib import pyplot as plt
import numpy as np
import pickle

# %%
with open('pipes_and_shifts.pickle','rb') as f:
    pipes, shifts = pickle.load(f)
pipe = pipes[1]

# %%
# pipe.build_plotting_data(density=50)

# %%
xs = pipe.xs
ys = pipe.ys
z = xs + 1j*ys
omega = pipe.omegas[0]

# %%
u, v, p, o = pipe.fields_with_fluxes(np.array([1]),base_let_index=0,base_pressure=0)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(xs,ys,c=p,s=1)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(xs,ys,c=o,s=1)

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig.colorbar(ax.scatter(xs,ys,c=np.log(np.abs(o)),s=1))

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig.colorbar(ax.scatter(xs,ys,c=u,s=1))

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig.colorbar(ax.scatter(xs,ys,c=v,s=1))
