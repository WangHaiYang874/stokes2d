# %%
from caps import smooth_cap
from matplotlib import pyplot as plt
import numpy as np

# %%
cap = smooth_cap()
plt.plot(cap.x,cap.y)
plt.title('the standard cap')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
t = np.sqrt(cap.get_t())

# %%
plt.plot(t.real,t.imag)

# %% [markdown]
# this is rather a difficult problem to generate a good enough corners.
